# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df= pd.read_csv('../yfinance_Project/stock_nse.csv')

# %%
df
# Out:
#       Unnamed: 0        Date        Close         High          Low  \
# 0              0  2025-01-01   879.486938   885.036919   868.806297
# 1              1  2025-01-02   884.913635   889.698928   874.677004
# 2              2  2025-01-03   862.935669   885.653615   861.505055
# 3              3  2025-01-06   843.843811   866.882376   841.525176
# 4              4  2025-01-07   845.274414   849.023722   838.663758
# ...          ...         ...          ...          ...          ...
# 2745         270  2026-02-02  1311.500000  1352.699951  1302.900024
# 2746         271  2026-02-03  1356.199951  1418.300049  1345.500000
# 2747         272  2026-02-04  1338.699951  1369.900024  1336.599976
# 2748         273  2026-02-05  1330.599976  1340.000000  1317.400024
# 2749         274  2026-02-06  1341.599976  1346.400024  1324.699951
#
#              Open    Volume     Stock  index
# 0      874.898930   7313806  HDFCBANK    NaN
# 1      876.699651  18558576  HDFCBANK    NaN
# 2      883.556955  24426194  HDFCBANK    NaN
# 3      858.446416  18816348  HDFCBANK    NaN
# 4      846.063733  13527906  HDFCBANK    NaN
# ...           ...       ...       ...    ...
# 2745  1339.000000   8647298  AXISBANK    NaN
# 2746  1403.000000  10384723  AXISBANK    NaN
# 2747  1369.699951   6672251  AXISBANK    NaN
# 2748  1340.000000   3766488  AXISBANK    NaN
# 2749  1325.000000   5876574  AXISBANK    NaN
#
# [2750 rows x 9 columns]

# %%
df.dtypes
# Out:
# Unnamed: 0      int64
# Date           object
# Close         float64
# High          float64
# Low           float64
# Open          float64
# Volume          int64
# Stock          object
# index         float64
# dtype: object

# %%
df.Date = df.Date.astype('datetime64[ns]')

# %%
print (df.Stock.unique())
st=input("Enter stock Name=")
r=df[df.Stock==st] 

sb.lineplot(x=r.Date,y=r.Close)
plt.show()
# Out:
# ['HDFCBANK' 'ICICIBANK' 'SBIN' 'INDUSINDBK' 'BANKBARODA' 'UNIONBANK'
#  'KOTAKBANK' 'IDBI' 'PNB' 'AXISBANK']
# Enter stock Name= PNB
